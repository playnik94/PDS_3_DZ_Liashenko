# %%
import matplotlib.pyplot as plt
import seaborn as sns
import p

table = pd.read_excel('Cars2.xlsx')

Price = table.values[:, 2]
consumption = table.values[:, 5]
plt.plot(Price, consumption, color='green', linewidth=3)
plt.show()

# %%
Cars = pd.read_excel('Cars2.xlsx')
consumption = table.values[:, 5]
Max_Speed = table.values[:, 3]

plt.scatter(consumption, Max_Speed, color='red', marker='D')
plt.show()

# %%
Cars2 = pd.read_excel('Cars2.xlsx')
Load_capacity = table.values[:, 4]
Max_Speed = table.values[:, 3]

plt.scatter(Max_Speed, consumption, color='black', marker='D')
plt.show()

# %%
Cars2 = pd.read_excel('Cars2.xlsx')

Max_Speed = table.values[:, 3]
plt.hist(Max_Speed, 5, width= 8, color='green')
plt.show()

# %%
Cars3 = pd.read_excel('Cars2.xlsx')
Cars3.head(5)
sns.set_style("white")
sns.set_palette("husl")
sns.lineplot(data=Cars3, x="Price", y="CarName")
# Out:
# <Axes: xlabel='Price', ylabel='CarName'>

# %%
sns.boxplot(data=Cars3, x="MaxSpeed", y="CarName")
# Out:
# <Axes: xlabel='MaxSpeed', ylabel='CarName'>

# %%
sns.pairplot(Cars3)

# %%
Cars3.head()
# Out:
#    CarName  Year  Price  MaxSpeed  Loadcapacity  consumption
# 0     ritz  2014   3.35       100          7000           50
# 1      sx4  2013   4.75       110          3000            8
# 2     ciaz  2017   7.25       120           900            9
# 3  wagon r  2011   2.85       180           200           12
# 4    swift  2014   4.60       200          2450           15

# %%
Cars3.tail()
# Out:
#     CarName  Year  Price  MaxSpeed  Loadcapacity  consumption
# 14    dzire  2009   2.25       230          7427           30
# 15   ertiga  2016   7.75       140          3000           45
# 16   ertiga  2015   7.25       180          1678          100
# 17   ertiga  2016   7.75       165          3000           43
# 18  wagon r  2015   3.25       230           500            4
