# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import BaggingClassifier
from sklearn import datasets, metrics
from sklearn.model_selection import train_test_split
import seaborn as sns

# %%
full_df = datasets.load_breast_cancer()
x = full_df.data[::, 0:6]
y = full_df.target

feature = full_df.feature_names[:6]

df = pd.DataFrame(x, columns=list(feature))
df['y'] = y

print(df.shape)

df.head()
# Out:
# (569, 7)
#    mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0        17.99         10.38          122.80     1001.0          0.11840
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        11.42         20.38           77.58      386.1          0.14250
# 4        20.29         14.34          135.10     1297.0          0.10030
#
#    mean compactness  y
# 0           0.27760  0
# 1           0.07864  0
# 2           0.15990  0
# 3           0.28390  0
# 4           0.13280  0

# %%
sns.heatmap(df.isnull(), annot=False, cbar=True)
# Out:
# <AxesSubplot: >

# %%
print(max(df.iloc[::, 0]), min(df.iloc[::, 0]))
print(max(df.iloc[::, 1]), min(df.iloc[::, 1]))
# Out:
# 28.11 6.981
# 39.28 9.71

# %%
class_0 = df[y == 0]
class_1 = df[y == 1]

# %%
print(class_0.shape, class_1.shape)
# Out:
# (212, 7) (357, 7)

# %%
plt.figure(figsize=(8, 6))
plt.scatter(class_0.iloc[::, 0], class_0.iloc[::, 1], label='class 0')
plt.scatter(class_1.iloc[::, 0], class_1.iloc[::, 1], label='class 1')
plt.legend()

# %%
df.describe()
# Out:
#        mean radius  mean texture  mean perimeter    mean area  \
# count   569.000000    569.000000      569.000000   569.000000
# mean     14.127292     19.289649       91.969033   654.889104
# std       3.524049      4.301036       24.298981   351.914129
# min       6.981000      9.710000       43.790000   143.500000
# 25%      11.700000     16.170000       75.170000   420.300000
# 50%      13.370000     18.840000       86.240000   551.100000
# 75%      15.780000     21.800000      104.100000   782.700000
# max      28.110000     39.280000      188.500000  2501.000000
#
#        mean smoothness  mean compactness           y
# count       569.000000        569.000000  569.000000
# mean          0.096360          0.104341    0.627417
# std           0.014064          0.052813    0.483918
# min           0.052630          0.019380    0.000000
# 25%           0.086370          0.064920    0.000000
# 50%           0.095870          0.092630    1.000000
# ...

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=42)

# %%
model_b = BaggingClassifier(estimator=DecisionTreeClassifier(), n_estimators=10, random_state=42)
model_b.fit(x_train, y_train)
# Out:
# BaggingClassifier(estimator=DecisionTreeClassifier(), random_state=42)

# %%
y_pred_test = model_b.predict(x_test)
y_pred_train = model_b.predict(x_train)

print(metrics.accuracy_score(y_test, y_pred_test))
print(metrics.accuracy_score(y_train, y_pred_train))
# Out:
# 0.9473684210526315
# 0.992462311557789

# %%
model_b.score(x_train, y_train)
# Out:
# 0.992462311557789

# %% [markdown]
# ---------------------

# %%
model_tee_D = DecisionTreeClassifier(random_state=42, max_depth=3)
model_tee_D.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier(max_depth=3, random_state=42)

# %%
y_predict_test = model_tee_D.predict(x_test)
y_predict_train = model_tee_D.predict(x_train)

print(metrics.accuracy_score(y_test, y_predict_test))
print(metrics.accuracy_score(y_train, y_predict_train))
# Out:
# 0.9181286549707602
# 0.9271356783919598

# %%
plt.figure(figsize=(60, 60))
plot_tree(model_tee_D, feature_names=list(feature), filled=True)
plt.show()

# %% [markdown]
# ----------------------------------

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.ensemble import StackingClassifier, StackingRegressor
from sklearn.datasets import make_regression, make_classification
from sklearn import metrics
from sklearn import pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import RepeatedStratifiedKFold, cross_val_score
import numpy as np
import matplotlib.pyplot as plt

# %%
X, Y = make_classification(n_samples=1000, n_features=20, n_informative=15, n_redundant=5, random_state=1)

print(np.bincount(Y))
print(X.shape, Y.shape)
# Out:
# [501 499]
# (1000, 20) (1000,)

# %%
def get_models():
    
    models = dict()
    models['lr'] = LogisticRegression()
    models['knn'] = KNeighborsClassifier()
    models['cart'] = DecisionTreeClassifier()
    models['svm'] = SVC()
    models['bayes'] = GaussianNB()
    return models

# %%
def evaluate_model(model, x, y):
    cv = RepeatedStratifiedKFold(n_splits=10, n_repeats=3, random_state=1)
    score = cross_val_score(model, x, y, scoring='accuracy', cv=cv, n_jobs=-1, error_score='raise')
    return score

# %%
models = get_models()

results, names = list(), list()
for name, model in models.items():
    scores = evaluate_model(model, X, Y)

    results.append(scores)
    names.append(name)

    print('>%s %.3f (%.3f)' % (name, np.mean(scores), np.std(scores)))


plt.boxplot(results, labels=names, showmeans=True)
plt.show()
# Out:
# >lr 0.866 (0.029)
# >knn 0.931 (0.025)
# >cart 0.829 (0.048)
# >svm 0.957 (0.020)
# >bayes 0.833 (0.031)

# %%
def get_stacking():

    level0 = list()
    level0.append(('lr', LogisticRegression()))
    level0.append(('knn', KNeighborsClassifier()))
    level0.append(('cart', DecisionTreeClassifier()))
    level0.append(('svm', SVC()))
    level0.append(('bayes', GaussianNB()))

    level1 = LogisticRegression()

    model = StackingClassifier(estimators=level0, final_estimator=level1, cv=5)
    return model

# %%
def get_models():
    models = dict()
    models['lr'] = LogisticRegression()
    models['knn'] = KNeighborsClassifier()
    models['cart'] = DecisionTreeClassifier()
    models['svm'] = SVC()
    models['bayes'] = GaussianNB()
    models['stacking'] = get_stacking()
    return models

# %%
models = get_models()

results, names = list(), list()
for name, model in models.items():
    
    scores = evaluate_model(model, X, Y)
    results.append(scores)
    names.append(name)
    print('>%s %.3f (%.3f)' % (name, np.mean(scores), np.std(scores)))

meas = [np.mean(i) for i in results]
print('max: ', names[meas.index(np.max(meas))], np.max(meas))
plt.boxplot(results, labels=names, showmeans=True)
plt.show()
# Out:
# >lr 0.866 (0.029)
# >knn 0.931 (0.025)
# >cart 0.829 (0.045)
# >svm 0.957 (0.020)
# >bayes 0.833 (0.031)
# >stacking 0.965 (0.018)
# max:  stacking 0.9653333333333334

# %% [markdown]
# -----------------

# %%
level0 = list()
level0.append(('lr', LogisticRegression()))
level0.append(('kn', KNeighborsClassifier()))
level0.append(('dtree', DecisionTreeClassifier()))
level0.append(('svm', SVC()))
level0.append(('ga', GaussianNB()))

level1 = LogisticRegression()
# Out:
# [('lr', LogisticRegression()), ('kn', KNeighborsClassifier()), ('dtree', DecisionTreeClassifier()), ('svm', SVC()), ('ga', GaussianNB())]

# %%
model = StackingClassifier(estimators=level0, final_estimator=level1, cv=5)
model.fit(X, Y)
# Out:
# StackingClassifier(cv=5,
#                    estimators=[('lr', LogisticRegression()),
#                                ('kn', KNeighborsClassifier()),
#                                ('dtree', DecisionTreeClassifier()),
#                                ('svm', SVC()), ('ga', GaussianNB())],
#                    final_estimator=LogisticRegression())

# %%
y_pred = model.predict(X)

print(metrics.accuracy_score(Y, y_pred))
# Out:
# 0.985

# %%
data = [[2.47475454,0.40165523,1.68081787,2.88940715,0.91704519,-3.07950644,4.39961206,0.72464273,-4.86563631,-6.06338084,-1.22209949,-0.4699618,1.01222748,-0.6899355,-0.53000581,6.86966784,-3.27211075,-6.59044146,-2.21290585,-3.139579]]
yhat = model.predict(data)
print('Predicted Class: %d' % (yhat))
# Out:
# Predicted Class: 0

# %% [markdown]
# _____________

# %%
model_logic = LogisticRegression()
model_logic.fit(X, Y)
# Out:
# LogisticRegression()

# %%
y_pred_log = model_logic.predict(X)

print(metrics.accuracy_score(Y, y_pred_log))
# Out:
# 0.875

# %%
model_logic.predict(data)
# Out:
# array([0])

# %% [markdown]
# -----------------------

# %% [markdown]
# Statcking_Regressor

# %%
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.svm import SVR
from sklearn.model_selection import KFold, RepeatedKFold

# %%
x, y = make_regression(n_samples=1000, n_features=20, n_informative=15, noise=0.1, random_state=1)

# %%
def models_reg():
    model = list()
    model.append(('LR', LinearRegression()))
    model.append(('DT', DecisionTreeRegressor()))
    model.append(('KN', KNeighborsRegressor()))
    model.append(('SVM', SVR()))
    return model

# %%
def evaluate_model_reg(model, x, y):
    cv = RepeatedKFold(n_splits=10, n_repeats=3, random_state=1)
    scores = cross_val_score(model, x, y, scoring='neg_mean_absolute_error', cv=cv, error_score='raise')
    return scores

# %%
result_model = list()
names_model = list()

for n, m in models_reg():

    s = evaluate_model_reg(m, x, y)
    result_model.append(s)
    names_model.append(n)
    
    print('>%s %.3f (%3.f)' % (n, np.mean(s), np.std(s)))
    
plt.boxplot(result_model, labels=names_model, showmeans=True)
plt.show()
# Out:
# >LR -0.083 (  0)
# >DT -146.569 ( 10)
# >KN -101.019 (  7)
# >SVM -162.419 ( 13)
