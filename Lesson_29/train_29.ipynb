# %% [markdown]
# ![%D0%A1%D0%BD%D0%B8%D0%BC%D0%BE%D0%BA%20%D1%8D%D0%BA%D1%80%D0%B0%D0%BD%D0%B0%202024-04-13%20145136.png](attachment:%D0%A1%D0%BD%D0%B8%D0%BC%D0%BE%D0%BA%20%D1%8D%D0%BA%D1%80%D0%B0%D0%BD%D0%B0%202024-04-13%20145136.png)

# %%
xi = [156, 160, 164, 168, 172, 176, 180, 184]
ni = [8, 14, 20, 32, 12, 8, 4, 2]

n = sum(ni)

print(xi)
print(ni)
print(n)
# Out:
# [156, 160, 164, 168, 172, 176, 180, 184]
# [8, 14, 20, 32, 12, 8, 4, 2]
# 100

# %%
X = []
for x, n in zip(xi, ni):
    X.append(x * n)

X = sum(X)

X = 1 / 100 * X

print(X)
# Out:
# 167.04

# %%
D = []
for x, n in zip(xi, ni):
    D.append(x**2 * n)

D = sum(D)

D = 1 / 100 * D - X**2

print(D)
# Out:
# 40.67840000000433

# %%
G = D**0.5

print(G)
# Out:
# 6.377962056958659

# %%
############### | (Zi-1 ; Zi) | Fi (Zi -1) | Fi (Zi)  |  pi   |  ni! = 100 pi | # Интервалы

############### Zi-1 = ai - 1 - x! / G

############### Zi = ai - x! / G

############### n! = n * pi

############### xi - X / G = 158 - 167.04 / 6.38

# %%
(158 - 167.04) / 6.38
# Out:
# -1.416927899686519

# %%
Zi_1 = []
for x in xi:
    Zi_1.append((x + 2 - X) / G )

Zi_1  # от - бесконечности до + бесконечности
# Out:
# [-1.4173806490643706,
#  -0.7902210698323476,
#  -0.1630614906003247,
#  0.4640980886316982,
#  1.0912576678637211,
#  1.718417247095744,
#  2.345576826327767,
#  2.9727364055597896]

# %%
f = [-0.4222, -0.2852, -0.0636, 0.1772, 0.3621, 0.4573, 0.4904,]


for z, zi, F, in zip(Zi_1, Zi_1[1:], f):

    print(f'{round(z, 2)} : { round(zi, 2)} = {F}')
# Out:
# -1.42 : -0.79 = -0.4222
# -0.79 : -0.16 = -0.2852
# -0.16 : 0.46 = -0.0636
# 0.46 : 1.09 = 0.1772
# 1.09 : 1.72 = 0.3621
# 1.72 : 2.35 = 0.4573
# 2.35 : 2.97 = 0.4904

# %% [markdown]
# p1 = F(zi_1) - F(zi)

# %%
n = 100

# %%
Zi_1 = [-0.5, -0.4222, -0.2852, -0.0636, 0.1772, 0.3621, 0.4573, 0.4904,] # По таблице Лапласа 
Zi = [-0.4222, -0.2852, -0.0636, 0.1772, 0.3621, 0.4573, 0.4904, 0.5]

Pi = []
ni_ = []

for i, j in zip(Zi_1, Zi):
    pi = (round(i - j, 4))
    Pi.append(pi)
    ni_.append(round(n * abs(pi)))
    print(f'{i}  |  {j}  |  {abs(pi)} | {round(n * abs(pi))}')
# Out:
# -0.5  |  -0.4222  |  0.0778 | 8
# -0.4222  |  -0.2852  |  0.137 | 14
# -0.2852  |  -0.0636  |  0.2216 | 22
# -0.0636  |  0.1772  |  0.2408 | 24
# 0.1772  |  0.3621  |  0.1849 | 18
# 0.3621  |  0.4573  |  0.0952 | 10
# 0.4573  |  0.4904  |  0.0331 | 3
# 0.4904  |  0.5  |  0.0096 | 1

# %%
################## K_емп = (ni - ni!)**2 / ni!

# %% [markdown]
# --------------------------------

# %% [markdown]
# ----------------------------

# %%
# Example of the Pearson's Correlation test
from scipy.stats import pearsonr
data1 = [0.873, 2.817, 0.121, -0.945, -0.055, -1.436, 0.360, -1.478, -1.637, -1.869]
data2 = [0.353, 3.517, 0.125, -7.545, -0.555, -1.536, 3.350, -1.578, -3.537, -1.579]
stat, p = pearsonr(data1, data2)
print('stat=%.3f, p=%.3f' % (stat, p))
if p > 0.05:
 print('Probably independent')
else:
 print('Probably dependent')
# Out:
# stat=0.688, p=0.028
# Probably dependent

# %%
# generate related variables
import numpy as np
import matplotlib.pyplot as plt

# seed random number generator
np.random.seed(1)
# prepare data
data1 = 20 * np.random.randn(1000) + 100
data2 = data1 + (10 * np.random.randn(1000) + 50)
# summarize
print('data1: mean=%.3f stdv=%.3f' % (np.mean(data1), np.std(data1)))
print('data2: mean=%.3f stdv=%.3f' % (np.mean(data2), np.std(data2)))
# plot
plt.scatter(data1, data2)
plt.show()
# Out:
# data1: mean=100.776 stdv=19.620
# data2: mean=151.050 stdv=22.358
# <img src="data:image/png;base64,..." width="640">

# %%
print(len(data1))
print(max(data1))
print(min(data1))
print(np.mean(data1))
# Out:
# 1000
# 179.17205408075927
# 38.9247123914739
# 100.77624952319204

# %%
print(len(data2))
print(max(data2))
print(min(data2))
print(np.mean(data2))
# Out:
# 1000
# 232.11913022252924
# 80.02282938575354
# 151.0495039571378

# %%
covariation = np.cov(data1, data2)

P_corr_coff = covariation / (np.std(data1) * np.std(data2))

print(covariation)
print()
print(P_corr_coff)
# Out:
# [[385.33297729 389.7545618 ]
#  [389.7545618  500.38006058]]
#
# [[0.87842078 0.88850041]
#  [0.88850041 1.14068681]]

# %%
import scipy.stats as st

corr, _ = st.spearmanr(data1, data2)
print('Spearmans correlation: %.3f' % corr)
# Out:
# Spearmans correlation: 0.872

# %%
from scipy.stats import chi2_contingency
table = [[10, 20, 30],[6,  9,  17]]
stat, p, dof, expected = chi2_contingency(table)
print('stat=%.3f, p=%.3f' % (stat, p))
if p > 0.05:
 print('Probably independent')
else:
 print('Probably dependent')
# Out:
# stat=0.272, p=0.873
# Probably independent

# %%
from statsmodels.tsa.stattools import adfuller
data = [0, 1, 1, 5, 4, 7, 60, 7, 83, 9]
stat, p, lags, obs, crit, t = adfuller(data)
print('stat=%.3f, p=%.3f' % (stat, p))
if p > 0.05:
 print('Probably not Stationary')
else:
 print('Probably Stationary')
# Out:
# stat=0.129, p=0.968
# Probably not Stationary

# %%
# Example of the Student's t-test
from scipy.stats import ttest_ind
data1 = [0.873, 2.817, 0.121, -0.945, -0.055, -1.436, 0.360, -1.478, -1.637, -1.869]
data2 = [1.142, -0.432, -0.938, -0.729, -0.846, -0.157, 0.500, 1.183, -1.075, -0.169]
stat, p = ttest_ind(data1, data2)
print('stat=%.3f, p=%.3f' % (stat, p))
if p > 0.05:
 print('Probably the same distribution')
else:
 print('Probably different distributions')
# Out:
# stat=-0.326, p=0.748
# Probably the same distribution

# %%
import numpy as np

print(np.std(data1), np.std(data2))
# Out:
# 1.3820933000344078 0.7902385019726639

# %%
print(np.mean(data1), np.mean(data2))
# Out:
# -0.32489999999999997 -0.15209999999999996

# %%
# Example of the Paired Student's t-test
from scipy.stats import ttest_rel
data1 = [0.873, 2.817, 0.121, -0.945, -0.055, -1.436, 0.360, -1.478, -1.637, -1.869]
data2 = [1.142, -0.432, -0.938, -0.729, -0.846, -0.157, 0.500, 1.183, -1.075, -0.169]
stat, p = ttest_rel(data1, data2)
print('stat=%.3f, p=%.3f' % (stat, p))
if p > 0.05:
 print('Probably the same distribution')
else:
 print('Probably different distributions')
# Out:
# stat=-0.334, p=0.746
# Probably the same distribution

# %%
print(np.mean(data1), np.mean(data2))
# Out:
# -0.32489999999999997 -0.15209999999999996

# %%
from scipy.stats import f_oneway
data1 = [0.873, 2.817, 0.121, -0.945, -0.055, -1.436, 0.360, -1.478, -1.637, -1.869]
data2 = [1.142, -0.432, -0.938, -0.729, -0.846, -0.157, 0.500, 1.183, -1.075, -0.169]
data3 = [-0.208, 0.696, 0.928, -1.148, -0.213, 0.229, 0.137, 0.269, -0.870, -1.204]
stat, p = f_oneway(data1, data2, data3)
print('stat=%.3f, p=%.3f' % (stat, p))
if p > 0.05:
 print('Probably the same distribution')
else:
 print('Probably different distributions')
# Out:
# stat=0.096, p=0.908
# Probably the same distribution

# %%
xi = [12, 36, 60, 84, 108, 132, 156, 180, 204]
x = [24, 48, 72, 96, 120, 144, 168, 192, 216]
ni = [1, 2, 4, 6, 12, 16, 6, 2 , 1]

n = sum(ni)
a = 0.01

# %%
mx = []


for i, j in zip(xi, ni):
    mx.append(i * j)
    
mx = sum(mx)
mx = mx / n

print(mx)
# Out:
# 114.72

# %%
dx = []

for a, b in zip(xi, ni):
    dx.append(a**2 * b)
    
dx = sum(dx) / n
dx = dx - mx**2


print(dx)
# Out:
# 1452.441600000002

# %%
s = dx**0.5
print(s)
# Out:
# 38.1109118232561

# %%
Zi_1 = []


for i in x:
    Zi_1.append(round((i - mx) / s, 3))


print(Zi_1)
# Out:
# [-2.38, -1.751, -1.121, -0.491, 0.139, 0.768, 1.398, 2.028, 2.658]

# %%
zi_1 = [-0.4913, -0.4599, -0.3686, -0.1879, 0.0556, 0.2793, 0.3508, 0.4803, 0.5]
zi =   [-0.5, -0.4913, -0.4599, -0.3686, -0.1879, 0.0556, 0.2793, 0.3508, 0.4960]

# %%
for j, k in zip(zi, zi_1):
    print(j, k)
# Out:
# -0.5 -0.4913
# -0.4913 -0.4599
# -0.4599 -0.3686
# -0.3686 -0.1879
# -0.1879 0.0556
# 0.0556 0.2793
# 0.2793 0.3508
# 0.3508 0.4803
# 0.496 0.5

# %%
pi = []
n_i = []

for i, j in zip(zi_1, zi):
    pi.append(round(abs(i - j), 3))

print(pi)

for i in pi:
    n_i.append(round(n * i))

n_i = [1 if i == 0 in n_i else i for i in n_i]

print(n_i)
# Out:
# [0.009, 0.031, 0.091, 0.181, 0.243, 0.224, 0.072, 0.13, 0.004]
# [1, 2, 5, 9, 12, 11, 4, 6, 1]

# %%
for a, b, c, d, e in zip(Zi_1, zi, zi_1, pi, n_i):
    print(f'{a} : {b} : {c} : {d} : {e}')
# Out:
# -2.38 : -0.5 : -0.4913 : 0.009 : 1
# -1.751 : -0.4913 : -0.4599 : 0.031 : 2
# -1.121 : -0.4599 : -0.3686 : 0.091 : 5
# -0.491 : -0.3686 : -0.1879 : 0.181 : 9
# 0.139 : -0.1879 : 0.0556 : 0.243 : 12
# 0.768 : 0.0556 : 0.2793 : 0.224 : 11
# 1.398 : 0.2793 : 0.3508 : 0.072 : 4
# 2.028 : 0.3508 : 0.4803 : 0.13 : 6
# 2.658 : 0.496 : 0.5 : 0.004 : 1

# %%
n_i_ni2 = []

for i, j in zip(ni, n_i):
    n_i_ni2.append((i - j)**2 / j)

k_emp = sum(n_i_ni2)
k_emp
# Out:
# 7.139393939393939

# %%
r = 9 - 2 - 1

k_kr = 16.9

print(r)
print(k_emp)
# Out:
# 6
# 7.139393939393939

# %%
if k_kr > k_emp:
    print(f'K-емпирические | {k_emp} <  {k_kr} | К-ритических : Ho Нулевая гипотеза подтверждается от нормальном распределении')
else:
    print(f'K-емпирические | {k_emp} <  {k_kr} | К-ритических :   : H1 Гипотеза подтверждается о не нормальном распределении')
# Out:
# K-емпирические | 7.139393939393939 <  16.9 | К-ритических : Ho Нулевая гипотеза подтверждается от нормальном распределении

# %% [markdown]
# Задача 2:

# %%
import matplotlib.pyplot as plt

xi = [1, 2, 3]
P = [0.2, 0.2, 0.6]
print(sum(pi))


plt.figure(figsize=(8, 5))
plt.grid(True)
plt.plot(xi, P, 'o')
plt.xlabel('xi')
plt.ylabel('pi')
# Out:
# 1.0
# Text(0, 0.5, 'pi')

# %%
x =  [-3, 3, 7]
pi = [0.3, 0.3, 0.4]

mx = []

for i, j in zip(xi, P):
    mx.append(i * j)

mx = sum(mx)

round(mx)
# Out:
# 2

# %%
plt.figure(figsize=(8, 5))
plt.grid(True)
plt.plot(x, pi, 'o')
plt.xlabel('xi')
plt.ylabel('pi')
# Out:
# Text(0, 0.5, 'pi')

# %%
# P(X > =3) = 0.4
# P(3 <= X <+ ∞) 

# F(+∞) - F(3) 

F3 = 1 - 0.4
F3
# Out:
# 0.6

# %% [markdown]
#                                        | 0   if   x<= 1.4
#                                        |
#                                        | 0.3 if   1.4 < x <= 1.5
#                                        |
#                                        | 0.6 if   1.5 < x <= 3
#                                        |
#                                        |  1  if     x > 3

# %%
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')


X = [[0, 1.4], [1.4, 1.5], [1.5, 3], [3, 5]] 
P = [0, 0.3,  0.6,  1]


plt.figure(figsize=(8, 5))
plt.grid(True)
plt.plot(X, P, 'o')
plt.xlabel('xi')
plt.ylabel('pi')
# Out:
# Text(0, 0.5, 'pi')

# %%
import numpy as np
import matplotlib.pyplot as plt

t1 = np.linspace(0, 1, 1000)
t2 = np.linspace(0, 0.5, 1000)

plt.figure(figsize=(10,5))

plt.subplot(121)
plt.plot(t1, np.sin(t1 * np.pi))

plt.subplot(122)
plt.plot(t2, np.sin(t2 * np.pi))

plt.show()

# %% [markdown]
# Відомо що P(X>=3) = 0.4, M(X) = 2
#
# Проміжок можливих значень рівномірно розподіленої випадкової величини є [a;b], тоді функція щільності розподілу має вигляд: f(x) = 0, якщо x < a f(x) = 1 / (b-a), якщо a < x <= b f(x) = 0, якщо x > b
#
# Формула математичного сподівання буде мати вигляд: M(X) = ∫ba x / (b-a) dx
#
# Визначимо проміжок (а;b) зміни випадкової величини склавши систему рівнянь
#
# ∫b3 1 / (b-a) dx = 0.4 ∫ba x / (b-a) dx = 2
#
# x / (b-a) |b3 = 0.4 x2 / 2(b-a) |ba = 2
#
# (b-3) / (b-a) = 0.4 (b2 - a2) / 2(b-a) = 2
#
# (b-3) / (b-a) = 0.4 (b+a) / 2 = 2
#
# 0.6b + 0.4a = 3 b = 4 - a
#
# a = -3 b = 7
#
# Отже, f(x) = 0, якщо x < -3 f(x) = 0.1, якщо -3 < x <= 7 f(x) = 0, якщо x > 7

# %%
import pandas as pd
from collections import Counter
import seaborn as sns
import pingouin as pg

df = pd.read_csv('seeds.csv')

dv = 'compactness'
iv = 'variety'
df.groupby(iv).mean()



kama = 0
Canadian = 0
rosa = 0

for i in df['variety']:
    if i == 'Kama':
        kama += 1
    if i == 'Rosa':
        rosa += 1
    if i == 'Canadian':
        Canadian += 1
        
print(rosa)
print(kama)
print(Canadian)
# Out:
# 70
# 70
# 70

# %%
df
# Out:
#       area  perimeter  compactness  kernel_length  kernel_width  \
# 0    15.26      14.84       0.8710          5.763         3.312
# 1    14.88      14.57       0.8811          5.554         3.333
# 2    14.29      14.09       0.9050          5.291         3.337
# 3    13.84      13.94       0.8955          5.324         3.379
# 4    16.14      14.99       0.9034          5.658         3.562
# ..     ...        ...          ...            ...           ...
# 205  12.19      13.20       0.8783          5.137         2.981
# 206  11.23      12.88       0.8511          5.140         2.795
# 207  13.20      13.66       0.8883          5.236         3.232
# 208  11.84      13.21       0.8521          5.175         2.836
# 209  12.30      13.34       0.8684          5.243         2.974
#
#      asymmetry_coef  kernel_groove_length   variety
# 0             2.221                 5.220      Kama
# 1             1.018                 4.956      Kama
# ...

# %%
fig, ax = plt.subplots(figsize = ( 8 , 6 )) 
ax.grid( False ) 
ax.set_frame_on( False ) 


sns.kdeplot(df, x=df['compactness'], hue=df['variety'], fill=False, ax = ax)
plt.show()

# %%
pg.normality(df, dv = dv, group = iv, method = 'shapiro')
# Out:
#                  W      pval  normal
# variety
# Kama      0.994840  0.993688    True
# Rosa      0.977010  0.225120    True
# Canadian  0.984481  0.539699    True

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
x = [np.mean(np.random.randint(1, 7, size=100)) for i in range(100)]

# %%
plt.hist(x)
# Out:
# (array([ 1.,  6., 13., 21., 15., 18., 11.,  8.,  4.,  3.]),
#  array([3.08 , 3.159, 3.238, 3.317, 3.396, 3.475, 3.554, 3.633, 3.712,
#         3.791, 3.87 ]),
#  <BarContainer object of 10 artists>)

# %%
def hash_function(text):

    return sum(ord(character) for character in repr(text))

# %%
hash_function('Lorem')
# Out:
# 589

# %%
hash_function('Lorme')
# Out:
# 589

# %%
type(repr('3.14'))
# Out:
# str

# %%
type(str('3.14'))
# Out:
# str

# %%
hash_function('3.14')
# Out:
# 276

# %%
hash_function(3.14)
# Out:
# 198

# %%
def hash_f(num):
    return sum(index * ord(n) for index, n in enumerate(repr(num), start=1))

# %%
hash_f(3.14)
# Out:
# 498

# %%
hash_f('Loren')
# Out:
# 2418

# %%
hash_f('Loner')
# Out:
# 2426
